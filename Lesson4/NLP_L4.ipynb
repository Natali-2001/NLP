# %% [markdown]
# ### 1. Объединить в одну выборку (это только для твитов), для роспотребнадзора сформировать датасет из вопросов

# %%
import pandas as pd
pd.set_option('display.max_columns', None)  
pd.set_option('display.expand_frame_repr', False)
pd.set_option('max_colwidth', None)

# %% [markdown]
# Загрузим датасет Роспотребнадзора

# %%
question = pd.read_csv('question.csv')
question
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           0
# 0                                                                                                                                                                                                                                                                                                                                                                                             Прошу Вас разобраться с магазином"Связной" По адресу Орловская обл. Ливенский р-он г. Ливны. Ул м. Горького д 7.претензия заключается в следующем:в данном магазине 16.10.2022 г. В 15:51 мск был куплен телефон Infinite Hot 12i и медиаплеер Sber box. Куплен был в кредит. Чек не предоставили, забрала только на следующий день. В данном чеке, мы увидели что сумма превышает стоимость телефона и медиаплеера, начали спрашивать у продавца, ответ не получили. В чеке прописаны и оформлены в кредит  сим карты мегафон 3 гшт по цене 1150.смс информирование 990 р. Защита кредита 490 р. Яндекс. Плюс мульти 2990.общая сумма моей покупки составила 19900.при том что я просила только телефон стоимость которого 8990 и медиаплеер стоимость которого 2990.Горячая линия данного магазина "Связной "отказалась решить тот вопрос.
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       Добрый день!\r\nПосле увольнения по собственному желанию не отдают трудовую книжку и запрошенные справки 2ндфл.\r\nПо телефону не берут трубку, чтобы можно было уточнить где и как можно забрать вышеупомянутую , прямой руководитель не отвечает( не берет трубку)\r\nОрганизация АО Почта России
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           21.09.2022 была заказана куртка Nike на озон ( в описании товара был заявлен этот бренд) после ожидания, длинною почти в месяц, 20.10.2022 эта куртка была мною получена. При осмотре куртки выяснилось, что куртка является контрафактной, имеет несоответствующие бирки. Поддержка озон предлагает лишь возврат товара, однако этот вариант меня не устраивает. Могу ли я получить моральную компенсацию? Прилагаю фотографии
# 3                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             Добрый вечер . Прошу обратить ваше внимание на так называемый медицинский центр «МИР ЗДОРОВЬЯ» , располагающегося по адресу г.Орел ул.Октябрьская 57. Обманывают пенсионеров , вводят в заблуждение . Абсолютно здоровый человек пройдя там бесплатную диагностику услышит , что для полного выздоровления ему необходимо у них купить приборы и препараты на сумму 200т + т.р. Предлагают рассрочки . Люди несут туда последние деньги ради чудесного исцеления.Всему этому есть подтверждение . Мошенники .
# 4                                                                                 Я, Морозова Елена Николаевна обращаюсь с жалобой на соседку живущую этажом выше Анну Нечипас ранее судимую, проживающую по адресу г. Тверь, Петербургское шоссе д. 50, кв. 312. На меня просачиваются нечистоты от соседки этажом выше. Управляющая компания воду ей отключила и холодную и горячую, т.к. у нее не был подсоединен унитаз и все что туда попадало все стекало в мою квартиру и она периодически меня заливала, то просто водой, то фекалиями. Сейчас она справляет нужду где попало и заливает водой из ведра, которую ей дают соседи, когда поднималась к ней видела у нее залитый пол. У меня в комнате за шкафом образовалась теч, капало и воняло фекалиями. Сейчас дома вонь, дома открыто окно, т.к. не возможно дышать вонью, очень холодно. Обращалась в полицию, мне ответили, что вопросами залива они не занимаются. Что подобные бытовые вопросы я должна решать сама. Анна Нечипас (соседка сверху) постоянно находится в наркотическом опьянении,  по этой причине договорится с ней не представляется возможным. Я пыталась с ней разговаривать, но Нечипас проявляет полную неадекватность.  Помогите решить этот вопрос!
# ..                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      ...
# 990                                                                                                                                                                                                                                                                                                                                                                                                                                                                             Здравствуйте.\r\nВ нашем доме есть мусоропровод, однако некоторые жильцы не утруждаются подняться/спуститься на полэтажа и оставляют мусор у подъезда. По некоторым из жильцов имеются доказательства их причастности, установлены камеры. К управляющей компании претензий нет – они убирают четко, каждый день, за исключением выходных. Однако тем не менее иногда могут скапливаться большие кучи бытовых отходов, которые воняют, и в целом не радуют глаз.  Насколько я знаю, УК штрафовать таких жильцов не имеет права, тем не менее исходя из изученной мною информации, действия жильцов не вполне законны.\r\nВ связи с этим, подскажите, пожалуйста, куда можно обратиться для решения данной ситуация, как можно повлиять на тех, кто мусорит?
# 991                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         Заказывала платья на сайте hardbofrty.ru, в итоге через Почту России пришла какая-то непонятная рубашка и еще какой-то мусор. На почте проверять посылку не стала, т.к. пришлось выждать очередь 40 минут и очень хотелось уйти из этого душного помещения. Дома открылась горькая правда. Сын в интернете обнаружил, что это мошенники и я не первая, кто на подобное попался. На их сайте не было ни телефона, ни адреса. Теперь вообще пишет какую-то ошибку 404. При попытке позвонить на их телефон, автомат каждый раз представляется новой компанией. На почтовом отправлении указана какая-то компания с ЕСПП 292313. Поиск также выдает доски с жалобами на мошенников. На чеке указана какая-то компания  Что делать?
# 992  12 июля, 2022 года в 0:15 по мск мне пришло уведомление, что с меня сняли 2970 рублей. 7 июля я заплатила за план питания 27 рублей, и никакой информации о последующих съёмов денег не было. План так и не пришёл, я успешно про него забыла, ибо не самые большие деньги. А вот снятие 2970 рублей стали для меня шоком. Во-первых, чек на оплату услуг зарегистрирован совсем под другим сайтом (не по питанию, а по садоводству). Во-вторых, когда я пытаюсь зайти в личный кабинет, мне пишут, что мой заказ не найден. Соответственно, даже если на платёж я, вероятно, согласилась, услуга не была оказана. Техподдержка ответила, что возвращать ничего не будут, можно отменить подписку. Подписку, которой нет. \r\nВсе чеки и документацию прилагаю. \r\nЧто на сайте planestfit.com, в личный кабинет которого я даже не могу войти, что на сайте q.domasad.com, где я тоже не могу ничего делать, указан один и тот же ИП Максимов Артем Алексеевич.\r\nБанк отказал в возврате платежа. Подскажите, что мне делать? Если подавать в суд, то куда обращаться. Хочу вернуть деньги хотя бы потому, что услуга не оказана. Но плюсом к этому - автоматическая подписка, из-за которой у меня сняли деньги без моего ведома.
# 993                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     Добрый день, в мае 2022 года был заключён договор с Зоогостиницей о пребывании в ней собаки с 31.07.22, и внесён авансовый платёж. В связи с изменением обстоятельств 28.06.22 обратились в гостиницу с просьбой отменить бронь и вернуть внесённый аванс, в ответ предложили написать заявление, которое осталось в приёмной со словами о том что нам перезвонит юрист в течение 14 дней. По истечению этого срока повторно обратились в организацию, получили ответ что с нами свяжутся. До сих пор ответа нет, денег нет, срок подходит к дате исполнения обязательств. Что нужно предпринять!?
# 994                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     Добрый день, в мае 2022 года был заключён договор с Зоогостиницей о пребывании в ней собаки с 31.07.22, и внесён авансовый платёж. В связи с изменением обстоятельств 28.06.22 обратились в гостиницу с просьбой отменить бронь и вернуть внесённый аванс, в ответ предложили написать заявление, которое осталось в приёмной со словами о том что нам перезвонит юрист в течение 14 дней. По истечению этого срока повторно обратились в организацию, получили ответ что с нами свяжутся. До сих пор ответа нет, денег нет, срок подходит к дате исполнения обязательств. Что нужно предпринять!?
#
# [995 rows x 1 columns]

# %%
data = question["0"].to_list()

# %%
data[:3]
# Out:
# ['Прошу Вас разобраться с магазином"Связной" По адресу Орловская обл. Ливенский р-он г. Ливны. Ул м. Горького д 7.претензия заключается в следующем:в данном магазине 16.10.2022 г. В 15:51 мск был куплен телефон Infinite Hot 12i и медиаплеер Sber box. Куплен был в кредит. Чек не предоставили, забрала только на следующий день. В данном чеке, мы увидели что сумма превышает стоимость телефона и медиаплеера, начали спрашивать у продавца, ответ не получили. В чеке прописаны и оформлены в кредит  сим карты мегафон 3 гшт по цене 1150.смс информирование 990 р. Защита кредита 490 р. Яндекс. Плюс мульти 2990.общая сумма моей покупки составила 19900.при том что я просила только телефон стоимость которого 8990 и медиаплеер стоимость которого 2990.Горячая линия данного магазина "Связной "отказалась решить тот вопрос. ',
#  'Добрый день!\r\nПосле увольнения по собственному желанию не отдают трудовую книжку и запрошенные справки 2ндфл.\r\nПо телефону не берут трубку, чтобы можно было уточнить где и как можно забрать вышеупомянутую , прямой руководитель не отвечает( не берет трубку)\r\nОрганизация АО Почта России',
#  '21.09.2022 была заказана куртка Nike на озон ( в описании товара был заявлен этот бренд) после ожидания, длинною почти в месяц, 20.10.2022 эта куртка была мною получена. При осмотре куртки выяснилось, что куртка является контрафактной, имеет несоответствующие бирки. Поддержка озон предлагает лишь возврат товара, однако этот вариант меня не устраивает. Могу ли я получить моральную компенсацию? Прилагаю фотографии']

# %%
len(data)
# Out:
# 995

# %% [markdown]
# ### 2. Провести исследование и выявить тематики о которых говорят в твитах (для твитов), а для роспотребнадзора так же выявить тематики о которых люди пишут проанализировать

# %% [markdown]
# ### Предобработка
#
#
# Стандартная предобработка текста

# %%
! pip install pymystem3
# Out:
# Requirement already satisfied: pymystem3 in c:\programdata\anaconda3\lib\site-packages (0.2.0)
# Requirement already satisfied: requests in c:\programdata\anaconda3\lib\site-packages (from pymystem3) (2.24.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\programdata\anaconda3\lib\site-packages (from requests->pymystem3) (1.25.11)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda3\lib\site-packages (from requests->pymystem3) (2020.6.20)
# Requirement already satisfied: idna<3,>=2.5 in c:\programdata\anaconda3\lib\site-packages (from requests->pymystem3) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\programdata\anaconda3\lib\site-packages (from requests->pymystem3) (3.0.4)

# %%
import re
import numpy as np
from nltk.corpus import stopwords
from tqdm.notebook import tqdm
from multiprocessing import Pool
from pymystem3 import Mystem

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\gladkova.RUSTG\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
! pip install pymorphy2
# Out:
# Requirement already satisfied: pymorphy2 in c:\programdata\anaconda3\lib\site-packages (0.9.1)
# Requirement already satisfied: pymorphy2-dicts-ru<3.0,>=2.4 in c:\programdata\anaconda3\lib\site-packages (from pymorphy2) (2.4.417127.4579844)
# Requirement already satisfied: dawg-python>=0.7.1 in c:\programdata\anaconda3\lib\site-packages (from pymorphy2) (0.7.2)
# Requirement already satisfied: docopt>=0.6 in c:\programdata\anaconda3\lib\site-packages (from pymorphy2) (0.6.2)

# %%
import pymorphy2
morph = pymorphy2.MorphAnalyzer()

# %%
words_regex = re.compile('\w+')

def find_words(text, regex = words_regex):
    tokens =  regex.findall(text.lower())
    return [w for w in tokens if w.isalpha() and len(w) >= 3]


stopwords_list = stopwords.words('russian')

def lemmatize(words, lemmer = morph, stopwords = stopwords_list):
    lemmas = [lemmer.parse(w)[0].normal_form for w in words]
    return [w for w in lemmas if not w in stopwords 
            and w.isalpha()]

def preprocess(text):
    return (lemmatize(find_words(text)))

# %%
data[1]
# Out:
# 'Добрый день!\r\nПосле увольнения по собственному желанию не отдают трудовую книжку и запрошенные справки 2ндфл.\r\nПо телефону не берут трубку, чтобы можно было уточнить где и как можно забрать вышеупомянутую , прямой руководитель не отвечает( не берет трубку)\r\nОрганизация АО Почта России'

# %%
print(preprocess(data[1]))
# Out:
# ['добрый', 'день', 'увольнение', 'собственный', 'желание', 'отдавать', 'трудовой', 'книжка', 'запросить', 'справка', 'телефон', 'брать', 'трубка', 'уточнить', 'забрать', 'вышеупомянутый', 'прямой', 'руководитель', 'отвечать', 'брать', 'трубка', 'организация', 'почта', 'россия']

# %% [markdown]
# Оставим случайные 10,000 текстов из нашей коллекции, для ускорения вычисления

# %%
preprocessed_text = list(tqdm(map(preprocess, data), total=len(data)))
# Out:
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=995.0), HTML(value='')))

# %%
data = preprocessed_text
data[:3]
# Out:
# [['просить',
#   'разобраться',
#   'магазин',
#   'связный',
#   'адрес',
#   'орловский',
#   'обл',
#   'ливенский',
#   'ливны',
#   'горький',
#   'претензия',
#   'заключаться',
#   'следующий',
#   'данный',
#   'магазин',
#   'мск',
#   'купить',
#   'телефон',
#   'infinite',
#   'hot',
#   'медиаплеер',
#   'sber',
#   'box',
#   'купить',
#   'кредит',
#   'чек',
#   'предоставить',
#   'забрать',
#   'следующий',
#   'день',
#   'данный',
#   'чек',
#   'увидеть',
#   'сумма',
#   'превышать',
#   'стоимость',
#   'телефон',
#   'медиаплеер',
#   'начать',
#   'спрашивать',
#   'продавец',
#   'ответ',
#   'получить',
#   'чек',
#   'прописать',
#   'оформить',
#   'кредит',
#   'сие',
#   'карта',
#   'мегафон',
#   'гшт',
#   'цена',
#   'смс',
#   'информирование',
#   'защита',
#   'кредит',
#   'яндекс',
#   'плюс',
#   'мультя',
#   'общий',
#   'сумма',
#   'покупка',
#   'составить',
#   'просить',
#   'телефон',
#   'стоимость',
#   'который',
#   'медиаплеер',
#   'стоимость',
#   'который',
#   'горячий',
#   'линия',
#   'данный',
#   'магазин',
#   'связный',
#   'отказаться',
#   'решить',
#   'вопрос'],
#  ['добрый',
#   'день',
#   'увольнение',
#   'собственный',
#   'желание',
#   'отдавать',
#   'трудовой',
#   'книжка',
#   'запросить',
#   'справка',
#   'телефон',
#   'брать',
#   'трубка',
#   'уточнить',
#   'забрать',
#   'вышеупомянутый',
#   'прямой',
#   'руководитель',
#   'отвечать',
#   'брать',
#   'трубка',
#   'организация',
#   'почта',
#   'россия'],
#  ['заказать',
#   'куртка',
#   'nike',
#   'озон',
#   'описание',
#   'товар',
#   'заявить',
#   'бренд',
#   'ожидание',
#   'длинный',
#   'месяц',
#   'куртка',
#   'получить',
#   'осмотр',
#   'куртка',
#   'выясниться',
#   'куртка',
#   'являться',
#   'контрафактный',
#   'иметь',
#   'несоответствующий',
#   'бирка',
#   'поддержка',
#   'озон',
#   'предлагать',
#   'лишь',
#   'возврат',
#   'товар',
#   'однако',
#   'вариант',
#   'устраивать',
#   'мочь',
#   'получить',
#   'моральный',
#   'компенсация',
#   'прилагать',
#   'фотография']]

# %% [markdown]
# ## Модель LDA
#
#
# Первая модель, которую мы рассмотрим, LDA - латентное размещение Дирихле. Воспользуемся реализацией из библиотеки gensim.

# %%
# !pip install -U gensim
# Out:
# Requirement already up-to-date: gensim in c:\programdata\anaconda3\lib\site-packages (4.2.0)
# Requirement already satisfied, skipping upgrade: scipy>=0.18.1 in c:\programdata\anaconda3\lib\site-packages (from gensim) (1.5.2)
# Requirement already satisfied, skipping upgrade: Cython==0.29.28 in c:\programdata\anaconda3\lib\site-packages (from gensim) (0.29.28)
# Requirement already satisfied, skipping upgrade: numpy>=1.17.0 in c:\programdata\anaconda3\lib\site-packages (from gensim) (1.19.2)
# Requirement already satisfied, skipping upgrade: smart-open>=1.8.1 in c:\programdata\anaconda3\lib\site-packages (from gensim) (6.2.0)

# %%
from gensim.models import *
from gensim import corpora
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\gensim\models\fasttext.py in <module>
#     263     )
# --> 264     from gensim.models.fasttext_corpusfile import train_epoch_sg, train_epoch_cbow
#     265 except ImportError:
#
# ImportError: DLL load failed while importing fasttext_corpusfile: Не найден указанный модуль.
#
# During handling of the above exception, another exception occurred:
#
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-17-a80aa2e36f53> in <module>
# ----> 1 from gensim.models import *
#       2 from gensim import corpora
#
# C:\ProgramData\Anaconda3\lib\site-packages\gensim\__init__.py in <module>
#       9 import logging
#      10
# ---> 11 from gensim import parsing, corpora, matutils, interfaces, models, similarities, utils  # noqa:F401
#      12
#      13
#
# C:\ProgramData\Anaconda3\lib\site-packages\gensim\models\__init__.py in <module>
#      20 from .atmodel import AuthorTopicModel  # noqa:F401
#      21 from .ldaseqmodel import LdaSeqModel  # noqa:F401
# ---> 22 from .fasttext import FastText  # noqa:F401
#      23 from .translation_matrix import TranslationMatrix, BackMappingTranslationMatrix  # noqa:F401
#      24 from .ensemblelda import EnsembleLda  # noqa:F401
#
# C:\ProgramData\Anaconda3\lib\site-packages\gensim\models\fasttext.py in <module>
#     264     from gensim.models.fasttext_corpusfile import train_epoch_sg, train_epoch_cbow
#     265 except ImportError:
# --> 266     raise utils.NO_CYTHON
#     267
#     268
#
# RuntimeError: Compiled extensions are unavailable. If you've installed from a package, ask the package maintainer to include compiled extensions. If you're building Gensim from source yourself, install Cython and a C compiler, and then run `python setup.py build_ext --inplace` to retry.

# %% [markdown]
# Модель использует векторное представление документов, например, мешок слов (bow), поэтому сперва создадим словарь:

# %%
dictionary = corpora.Dictionary(data)

dictionary.filter_extremes(no_below = 10, no_above = 0.9, keep_n=None) 
# игнорируем слова, которые встречаются реже 10 раз или составляют более 0.9 словаря 
dictionary.save('rpn.dict')

# %% [markdown]
# Векторизуем документы:

# %%
corpus = [dictionary.doc2bow(text) for text in data]
corpora.MmCorpus.serialize('rpn.model', corpus)

# %% [markdown]
# Теперь можем обучать модель:

# %%
lda = ldamodel.LdaModel(corpus, id2word=dictionary, num_topics=5, chunksize=50, update_every=1, passes=2)

# %% [markdown]
# Посмотрим на получившиеся темы:

# %%
lda.show_topics(num_topics=5, num_words=5, formatted=True)

# %% [markdown]
# ### 3. Сделать визуализацию кластеров тематик

# %% [markdown]
# На полученные темы можно посмотреть, изобразив их на плоскости с помощью библиотеки __pyLDAvis__. Чтобы спроецировать темы на плоскость, внутри применяется PCA-разложение.

# %%
# !pip install pyLDAvis

# %%
import pyLDAvis
import pyLDAvis.gensim_models as gensimvis
pyLDAvis.enable_notebook()

# %%
# %time vis_data = gensimvis.prepare(lda, corpus, dictionary)

# %%
pyLDAvis.display(vis_data)

# %% [markdown]
# Посмотрим на метрики качества получившейся модели: перплексию и среднюю когерентность:

# %%
print(lda.log_perplexity(corpus))

# %%
print('Персплексия: ', np.exp(lda.log_perplexity(corpus)))

# %%
coherence_model_lda = CoherenceModel(model=lda, texts=data, dictionary=dictionary, coherence='c_v')
coherence_lda = coherence_model_lda.get_coherence()
print('Средняя когерентность: ', coherence_lda)

# %% [markdown]
# Теперь можно подобрать оптимальное количество тем, опираясь на значение метрик:

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
topics_list = [2, 3, 4, 5, 6]
coherences = []

for num in tqdm(topics_list):
    lda = ldamodel.LdaModel(corpus, id2word=dictionary, num_topics=num, chunksize=50, update_every=1, passes=2)
    coherences.append(CoherenceModel(model=lda, texts=data, dictionary=dictionary, coherence='c_v').get_coherence())

plt.plot(topics_list, coherences)
plt.xlabel("Число тем")
plt.ylabel("Средняя когерентность")
plt.show()

# %%
lda_3 = ldamodel.LdaModel(corpus, id2word=dictionary, num_topics=3, chunksize=50, update_every=1, passes=2)

# %%
vis_data = gensimvis.prepare(lda_3, corpus, dictionary)
pyLDAvis.display(vis_data)

# %% [markdown]
# ### 4. проинтерпритировать получившиеся тематики
